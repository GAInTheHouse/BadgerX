# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# % cd 'NARR_2011'
# %mkdir dowloads_NARR

# %%
# %pwd
# Out:
# '/content'

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 93.19G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI457818/'
filelist = [
# 'NARR3D_201401_0103.nc.tar',
# 'NARR3D_201401_0406.nc.tar',
# 'NARR3D_201401_0709.nc.tar',
# 'NARR3D_201401_1012.nc.tar',
# 'NARR3D_201401_1315.nc.tar',
# 'NARR3D_201401_1618.nc.tar',
# 'NARR3D_201401_1921.nc.tar',
# 'NARR3D_201401_2224.nc.tar',
# 'NARR3D_201401_2527.nc.tar',
# 'NARR3D_201401_2831.nc.tar',
# 'NARR3D_201402_0103.nc.tar',
# 'NARR3D_201402_0406.nc.tar',
# 'NARR3D_201402_0709.nc.tar',
# 'NARR3D_201402_1012.nc.tar',
# 'NARR3D_201402_1315.nc.tar',
# 'NARR3D_201402_1618.nc.tar',
# 'NARR3D_201402_1921.nc.tar',
# 'NARR3D_201402_2224.nc.tar',
# 'NARR3D_201402_2527.nc.tar',
# 'NARR3D_201402_2828.nc.tar',
# 'NARR3D_201403_0103.nc.tar',
# 'NARR3D_201403_0406.nc.tar',
# 'NARR3D_201403_0709.nc.tar',
# 'NARR3D_201403_1012.nc.tar',
# 'NARR3D_201403_1315.nc.tar',
# 'NARR3D_201403_1618.nc.tar',
# 'NARR3D_201403_1921.nc.tar',
# 'NARR3D_201403_2224.nc.tar',
# 'NARR3D_201403_2527.nc.tar',
# 'NARR3D_201403_2831.nc.tar',
'NARR3D_201404_0103.nc.tar',
'NARR3D_201404_0406.nc.tar',
'NARR3D_201404_0709.nc.tar',
'NARR3D_201404_1012.nc.tar',
'NARR3D_201404_1315.nc.tar',
'NARR3D_201404_1618.nc.tar',
'NARR3D_201404_1921.nc.tar',
'NARR3D_201404_2224.nc.tar',
'NARR3D_201404_2527.nc.tar',
'NARR3D_201404_2830.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201404_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201404_2830.nc.tar
# 100.000 % Completed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 95.52G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI457819/'
filelist = [
'NARR3D_201405_0103.nc.tar',
'NARR3D_201405_0406.nc.tar',
'NARR3D_201405_0709.nc.tar',
'NARR3D_201405_1012.nc.tar',
'NARR3D_201405_1315.nc.tar',
'NARR3D_201405_1618.nc.tar',
'NARR3D_201405_1921.nc.tar',
'NARR3D_201405_2224.nc.tar',
'NARR3D_201405_2527.nc.tar',
'NARR3D_201405_2831.nc.tar',
'NARR3D_201406_0103.nc.tar',
'NARR3D_201406_0406.nc.tar',
'NARR3D_201406_0709.nc.tar',
'NARR3D_201406_1012.nc.tar',
'NARR3D_201406_1315.nc.tar',
'NARR3D_201406_1618.nc.tar',
'NARR3D_201406_1921.nc.tar',
'NARR3D_201406_2224.nc.tar',
'NARR3D_201406_2527.nc.tar',
'NARR3D_201406_2830.nc.tar',
# 'NARR3D_201407_0103.nc.tar',
# 'NARR3D_201407_0406.nc.tar',
# 'NARR3D_201407_0709.nc.tar',
# 'NARR3D_201407_1012.nc.tar',
# 'NARR3D_201407_1315.nc.tar',
# 'NARR3D_201407_1618.nc.tar',
# 'NARR3D_201407_1921.nc.tar',
# 'NARR3D_201407_2224.nc.tar',
# 'NARR3D_201407_2527.nc.tar',
# 'NARR3D_201407_2831.nc.tar',
# 'NARR3D_201408_0103.nc.tar',
# 'NARR3D_201408_0406.nc.tar',
# 'NARR3D_201408_0709.nc.tar',
# 'NARR3D_201408_1012.nc.tar',
# 'NARR3D_201408_1315.nc.tar',
# 'NARR3D_201408_1618.nc.tar',
# 'NARR3D_201408_1921.nc.tar',
# 'NARR3D_201408_2224.nc.tar',
# 'NARR3D_201408_2527.nc.tar',
# 'NARR3D_201408_2831.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201405_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201405_2831.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201406_2830.nc.tar
# 100.000 % Completed

# %%
# !pip3 install netcdf4
# Out:
# Collecting netcdf4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 12.1MB/s
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 40.5MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netcdf4) (1.18.5)
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.3.0 netcdf4-1.5.4

# %%
# !mkdir /content/data3
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
import glob 

for f in glob.glob("*.tar"): 
  print(f)
  os.system("tar -xvf  \"//content//{}\" -C /content/data3/".format(f))
  os.system("rm //content//{}".format(f))
# Out:
# NARR3D_201405_1315.nc.tar
# NARR3D_201406_1618.nc.tar
# NARR3D_201404_2224.nc.tar
# NARR3D_201406_1012.nc.tar
# NARR3D_201404_1618.nc.tar
# NARR3D_201406_2527.nc.tar
# NARR3D_201404_1012.nc.tar
# NARR3D_201405_0103.nc.tar
# NARR3D_201406_2224.nc.tar
# NARR3D_201405_1921.nc.tar
# NARR3D_201404_2830.nc.tar
# NARR3D_201406_1315.nc.tar
# NARR3D_201406_2830.nc.tar
# NARR3D_201405_2831.nc.tar
# NARR3D_201405_1618.nc.tar
# NARR3D_201405_0406.nc.tar
# NARR3D_201404_1315.nc.tar
# NARR3D_201405_2527.nc.tar
# NARR3D_201406_0709.nc.tar
# NARR3D_201404_2527.nc.tar
# NARR3D_201405_1012.nc.tar
# NARR3D_201406_0103.nc.tar
# NARR3D_201405_2224.nc.tar
# NARR3D_201404_0103.nc.tar
# NARR3D_201404_0709.nc.tar
# NARR3D_201404_0406.nc.tar
# NARR3D_201405_0709.nc.tar
# NARR3D_201406_0406.nc.tar
# NARR3D_201404_1921.nc.tar
# NARR3D_201406_1921.nc.tar

# %%
mts = ["04", "05", "06"]
mts_days = [30, 31 , 30]
dates = []

for i in range(len(mts)):
  dates += [ mts[i] + '{:02d}'.format(j+1) for j in range(mts_days[i])]

# %%
! pip netCDF4
# Out:
# ERROR: unknown command "netCDF4"

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 01:38:08 2020

@author: shreyanssaraogi
"""
from netCDF4 import Dataset
import numpy as np
import pandas as pd

for date in dates: 

  print(date)
  df = pd.DataFrame()
  datafiles = glob.glob('/content/data3/*2014{}*'.format(date))

  if datafiles == []:
    print(date + " is not available.")


  ts_total = []
  latarr_total = []
  lonarr_total = []
  temparr_total =[]
  humidityarr_total =[]
  vwindarr_total = []
  uwindarr_total = []
  cloud_water_total = []


  for j in range(len(datafiles)):
      datafile_name = datafiles[j]
      data = Dataset(datafile_name, 'r')


      # print(data.variables.keys())
      # print(data.variables)
      ct = 0
      latarr= []
      lonarr = []
      temparr =[]
      humidityarr =[]
      vwindarr = []
      uwindarr = []
      preparr= [] 

      
      ct = 0
      i = 0 


      
      
      
      for lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd in zip(data.variables['gridlat_221'][:], data.variables['gridlon_221'][:], data.variables['TMP_221_ISBL'][-1][:],data.variables['SPF_H_221_ISBL'][-1][:], data.variables['V_GRD_221_ISBL'][-1][:], data.variables['U_GRD_221_ISBL'][-1][:],data.variables['CLWMR_221_ISBL'][-1][:]):
          for lat, lon, tmp, hmd, vwind, uwind, prep in zip(lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd): 
              if((lat<43.0) and (lat>33.0) and (lon<-116.0) and (lon>-126.0) ):
                  latarr.append(lat)
                  lonarr.append(lon)
                  temparr.append(tmp)
                  humidityarr.append(hmd)
                  vwindarr.append(vwind)
                  uwindarr.append(uwind)
                  preparr.append(prep)



              ct += 1
              
      timestamp = datafile_name.split(".")[-3]
      #print(timestamp)
      
      ts_total += [timestamp] * len(latarr)
      latarr_total += latarr
      lonarr_total += lonarr
      temparr_total += temparr
      humidityarr_total += humidityarr
      vwindarr_total += vwindarr
      uwindarr_total += uwindarr
      cloud_water_total += preparr


      
      #print(ct)
      
  df["timestamp"]  = ts_total
  df["latitude"] = latarr_total
  df["longitude"] = lonarr_total
  df["temperature"] = temparr_total
  df["humidity"] = humidityarr_total
  df["v_component"] = vwindarr_total
  df["u_component"] = uwindarr_total
  df["precipitation"] = cloud_water_total

  from tabulate import tabulate
  #print(tabulate(df.head(n=5)))

  df.to_csv("2014{}.csv".format(date))
# Out:
# 0401
# 0402
# 0403
# 0404
# 0405
# 0406
# 0407
# 0408
# 0409
# 0410
# 0411
# 0412
# 0413
# 0414
# 0415
# 0416
# 0417
# 0418
# 0419
# 0420
# 0421
# 0422
# 0423
# 0424
# 0425
# 0426
# 0427
# 0428
# 0429
# 0430
# 0501
# 0502
# 0503
# 0504
# 0505
# 0506
# 0507
# 0508
# 0509
# 0510
# 0511
# 0512
# 0513
# 0514
# 0515
# 0516
# 0517
# 0518
# 0519
# 0520
# 0521
# 0522
# 0523
# 0524
# 0525
# 0526
# 0527
# 0528
# 0529
# 0530
# 0531
# 0601
# 0602
# 0603
# 0604
# 0605
# 0606
# 0607
# 0608
# 0609
# 0610
# 0611
# 0612
# 0613
# 0614
# 0615
# 0616
# 0617
# 0618
# 0619
# 0620
# 0621
# 0622
# 0623
# 0624
# 0625
# 0626
# 0627
# 0628
# 0629
# 0630

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !zip 2014_aprjun.zip *.csv
# Out:
#   adding: 20140401.csv (deflated 77%)
#   adding: 20140402.csv (deflated 77%)
#   adding: 20140403.csv (deflated 77%)
#   adding: 20140404.csv (deflated 76%)
#   adding: 20140405.csv (deflated 76%)
#   adding: 20140406.csv (deflated 76%)
#   adding: 20140407.csv (deflated 76%)
#   adding: 20140408.csv (deflated 76%)
#   adding: 20140409.csv (deflated 75%)
#   adding: 20140410.csv (deflated 74%)
#   adding: 20140411.csv (deflated 74%)
#   adding: 20140412.csv (deflated 75%)
#   adding: 20140413.csv (deflated 75%)
#   adding: 20140414.csv (deflated 75%)
#   adding: 20140415.csv (deflated 74%)
#   adding: 20140416.csv (deflated 75%)
#   adding: 20140417.csv (deflated 75%)
#   adding: 20140418.csv (deflated 75%)
#   adding: 20140419.csv (deflated 75%)
#   adding: 20140420.csv (deflated 75%)
#   adding: 20140421.csv (deflated 76%)
#   adding: 20140422.csv (deflated 75%)
#   adding: 20140423.csv (deflated 76%)
#   adding: 20140424.csv (deflated 75%)
#   adding: 20140425.csv (deflated 75%)
#   adding: 20140426.csv (deflated 77%)
#   adding: 20140427.csv (deflated 75%)
#   adding: 20140428.csv (deflated 75%)
#   adding: 20140429.csv (deflated 76%)
#   adding: 20140430.csv (deflated 76%)
#   adding: 20140501.csv (deflated 76%)
#   adding: 20140502.csv (deflated 76%)
#   adding: 20140503.csv (deflated 74%)
#   adding: 20140504.csv (deflated 74%)
#   adding: 20140505.csv (deflated 75%)
#   adding: 20140506.csv (deflated 76%)
#   adding: 20140507.csv (deflated 76%)
#   adding: 20140508.csv (deflated 75%)
#   adding: 20140509.csv (deflated 74%)
#   adding: 20140510.csv (deflated 75%)
#   adding: 20140511.csv (deflated 76%)
#   adding: 20140512.csv (deflated 75%)
#   adding: 20140513.csv (deflated 75%)
#   adding: 20140514.csv (deflated 76%)
#   adding: 20140515.csv (deflated 76%)
#   adding: 20140516.csv (deflated 75%)
#   adding: 20140517.csv (deflated 74%)
#   adding: 20140518.csv (deflated 75%)
#   adding: 20140519.csv (deflated 75%)
#   adding: 20140520.csv (deflated 75%)
#   adding: 20140521.csv (deflated 75%)
#   adding: 20140522.csv (deflated 75%)
#   adding: 20140523.csv (deflated 75%)
#   adding: 20140524.csv (deflated 75%)
#   adding: 20140525.csv (deflated 74%)
#   adding: 20140526.csv (deflated 75%)
#   adding: 20140527.csv (deflated 74%)
#   adding: 20140528.csv (deflated 75%)
#   adding: 20140529.csv (deflated 76%)
#   adding: 20140530.csv (deflated 75%)
#   adding: 20140531.csv (deflated 74%)
#   adding: 20140601.csv (deflated 74%)
#   adding: 20140602.csv (deflated 74%)
#   adding: 20140603.csv (deflated 75%)
#   adding: 20140604.csv (deflated 75%)
#   adding: 20140605.csv (deflated 75%)
#   adding: 20140606.csv (deflated 75%)
#   adding: 20140607.csv (deflated 75%)
#   adding: 20140608.csv (deflated 74%)
#   adding: 20140609.csv (deflated 74%)
#   adding: 20140610.csv (deflated 74%)
#   adding: 20140611.csv (deflated 74%)
#   adding: 20140612.csv (deflated 73%)
#   adding: 20140613.csv (deflated 75%)
#   adding: 20140614.csv (deflated 74%)
#   adding: 20140615.csv (deflated 74%)
#   adding: 20140616.csv (deflated 74%)
#   adding: 20140617.csv (deflated 75%)
#   adding: 20140618.csv (deflated 75%)
#   adding: 20140619.csv (deflated 75%)
#   adding: 20140620.csv (deflated 74%)
#   adding: 20140621.csv (deflated 74%)
#   adding: 20140622.csv (deflated 74%)
#   adding: 20140623.csv (deflated 74%)
#   adding: 20140624.csv (deflated 74%)
#   adding: 20140625.csv (deflated 74%)
#   adding: 20140626.csv (deflated 74%)
#   adding: 20140627.csv (deflated 74%)
#   adding: 20140628.csv (deflated 74%)
#   adding: 20140629.csv (deflated 75%)
#   adding: 20140630.csv (deflated 75%)

# %%
# !cp 2014_aprjun.zip drive/My\ Drive/'BadgerX Data'/NARR_2010_2019_data/NARR_2014
