# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip netCDF4
# Out:
# ERROR: unknown command "netCDF4"

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 95.52G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI458576/'
filelist = [
# 'NARR3D_201705_0103.nc.tar',
# 'NARR3D_201705_0406.nc.tar',
# 'NARR3D_201705_0709.nc.tar',
# 'NARR3D_201705_1012.nc.tar',
# 'NARR3D_201705_1315.nc.tar',
# 'NARR3D_201705_1618.nc.tar',
# 'NARR3D_201705_1921.nc.tar',
# 'NARR3D_201705_2224.nc.tar',
# 'NARR3D_201705_2527.nc.tar',
# 'NARR3D_201705_2831.nc.tar',
# 'NARR3D_201706_0103.nc.tar',
# 'NARR3D_201706_0406.nc.tar',
# 'NARR3D_201706_0709.nc.tar',
# 'NARR3D_201706_1012.nc.tar',
# 'NARR3D_201706_1315.nc.tar',
# 'NARR3D_201706_1618.nc.tar',
# 'NARR3D_201706_1921.nc.tar',
# 'NARR3D_201706_2224.nc.tar',
# 'NARR3D_201706_2527.nc.tar',
# 'NARR3D_201706_2830.nc.tar',
'NARR3D_201707_0103.nc.tar',
'NARR3D_201707_0406.nc.tar',
'NARR3D_201707_0709.nc.tar',
'NARR3D_201707_1012.nc.tar',
'NARR3D_201707_1315.nc.tar',
'NARR3D_201707_1618.nc.tar',
'NARR3D_201707_1921.nc.tar',
'NARR3D_201707_2224.nc.tar',
'NARR3D_201707_2527.nc.tar',
'NARR3D_201707_2831.nc.tar',
'NARR3D_201708_0103.nc.tar',
'NARR3D_201708_0406.nc.tar',
'NARR3D_201708_0709.nc.tar',
'NARR3D_201708_1012.nc.tar',
'NARR3D_201708_1315.nc.tar',
'NARR3D_201708_1618.nc.tar',
'NARR3D_201708_1921.nc.tar',
'NARR3D_201708_2224.nc.tar',
'NARR3D_201708_2527.nc.tar',
'NARR3D_201708_2831.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201707_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201707_2831.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201708_2831.nc.tar
# 100.000 % Completed

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 94.74G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI458577/'
filelist = [
'NARR3D_201709_0103.nc.tar',
'NARR3D_201709_0406.nc.tar',
'NARR3D_201709_0709.nc.tar',
'NARR3D_201709_1012.nc.tar',
'NARR3D_201709_1315.nc.tar',
'NARR3D_201709_1618.nc.tar',
'NARR3D_201709_1921.nc.tar',
'NARR3D_201709_2224.nc.tar',
'NARR3D_201709_2527.nc.tar',
'NARR3D_201709_2830.nc.tar',
# 'NARR3D_201710_0103.nc.tar',
# 'NARR3D_201710_0406.nc.tar',
# 'NARR3D_201710_0709.nc.tar',
# 'NARR3D_201710_1012.nc.tar',
# 'NARR3D_201710_1315.nc.tar',
# 'NARR3D_201710_1618.nc.tar',
# 'NARR3D_201710_1921.nc.tar',
# 'NARR3D_201710_2224.nc.tar',
# 'NARR3D_201710_2527.nc.tar',
# 'NARR3D_201710_2831.nc.tar',
# 'NARR3D_201711_0103.nc.tar',
# 'NARR3D_201711_0406.nc.tar',
# 'NARR3D_201711_0709.nc.tar',
# 'NARR3D_201711_1012.nc.tar',
# 'NARR3D_201711_1315.nc.tar',
# 'NARR3D_201711_1618.nc.tar',
# 'NARR3D_201711_1921.nc.tar',
# 'NARR3D_201711_2224.nc.tar',
# 'NARR3D_201711_2527.nc.tar',
# 'NARR3D_201711_2830.nc.tar',
# 'NARR3D_201712_0103.nc.tar',
# 'NARR3D_201712_0406.nc.tar',
# 'NARR3D_201712_0709.nc.tar',
# 'NARR3D_201712_1012.nc.tar',
# 'NARR3D_201712_1315.nc.tar',
# 'NARR3D_201712_1618.nc.tar',
# 'NARR3D_201712_1921.nc.tar',
# 'NARR3D_201712_2224.nc.tar',
# 'NARR3D_201712_2527.nc.tar',
# 'NARR3D_201712_2831.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201709_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201709_2830.nc.tar
# 100.000 % Completed

# %%
# !pip3 install netcdf4
# Out:
# Collecting netcdf4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 15.4MB/s
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 50.4MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netcdf4) (1.18.5)
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.3.0 netcdf4-1.5.4

# %%
# !mkdir /content/data3

# %%
import os 
import glob 

for f in glob.glob("*.tar"): 
  print(f)
  os.system("tar -xvf  \"//content//{}\" -C /content/data3/".format(f))
  os.system("rm //content//{}".format(f))
# Out:
# NARR3D_201707_0406.nc.tar
# NARR3D_201707_0709.nc.tar
# NARR3D_201707_2831.nc.tar
# NARR3D_201709_1921.nc.tar
# NARR3D_201708_0406.nc.tar
# NARR3D_201709_1012.nc.tar
# NARR3D_201708_2831.nc.tar
# NARR3D_201709_0103.nc.tar
# NARR3D_201708_1012.nc.tar
# NARR3D_201709_2224.nc.tar
# NARR3D_201707_2527.nc.tar
# NARR3D_201708_0709.nc.tar
# NARR3D_201707_1315.nc.tar
# NARR3D_201708_0103.nc.tar
# NARR3D_201709_0709.nc.tar
# NARR3D_201708_1315.nc.tar
# NARR3D_201707_1921.nc.tar
# NARR3D_201709_1315.nc.tar
# NARR3D_201709_2527.nc.tar
# NARR3D_201709_1618.nc.tar
# NARR3D_201708_2527.nc.tar
# NARR3D_201708_2224.nc.tar
# NARR3D_201707_2224.nc.tar
# NARR3D_201707_1012.nc.tar
# NARR3D_201709_2830.nc.tar
# NARR3D_201708_1921.nc.tar
# NARR3D_201707_0103.nc.tar
# NARR3D_201708_1618.nc.tar
# NARR3D_201709_0406.nc.tar
# NARR3D_201707_1618.nc.tar

# %%
mts = ["07", "08", "09"]
mts_days = [31, 31, 30]
dates = []

for i in range(len(mts)):
  dates += [ mts[i] + '{:02d}'.format(j+1) for j in range(mts_days[i])]

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 01:38:08 2020

@author: shreyanssaraogi
"""
from netCDF4 import Dataset
import numpy as np
import pandas as pd

for date in dates: 

  print(date)
  df = pd.DataFrame()
  datafiles = glob.glob('/content/data3/*2017{}*'.format(date))

  if datafiles == []:
    print(date + " is not available.")


  ts_total = []
  latarr_total = []
  lonarr_total = []
  temparr_total =[]
  humidityarr_total =[]
  vwindarr_total = []
  uwindarr_total = []
  cloud_water_total = []


  for j in range(len(datafiles)):
      datafile_name = datafiles[j]
      data = Dataset(datafile_name, 'r')


      # print(data.variables.keys())
      # print(data.variables)
      ct = 0
      latarr= []
      lonarr = []
      temparr =[]
      humidityarr =[]
      vwindarr = []
      uwindarr = []
      preparr= [] 

      
      ct = 0
      i = 0 


      
      
      
      for lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd in zip(data.variables['gridlat_221'][:], data.variables['gridlon_221'][:], data.variables['TMP_221_ISBL'][-1][:],data.variables['SPF_H_221_ISBL'][-1][:], data.variables['V_GRD_221_ISBL'][-1][:], data.variables['U_GRD_221_ISBL'][-1][:],data.variables['CLWMR_221_ISBL'][-1][:]):
          for lat, lon, tmp, hmd, vwind, uwind, prep in zip(lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd): 
              if((lat<43.0) and (lat>33.0) and (lon<-116.0) and (lon>-126.0) ):
                  latarr.append(lat)
                  lonarr.append(lon)
                  temparr.append(tmp)
                  humidityarr.append(hmd)
                  vwindarr.append(vwind)
                  uwindarr.append(uwind)
                  preparr.append(prep)



              ct += 1
              
      timestamp = datafile_name.split(".")[-3]
      #print(timestamp)
      
      ts_total += [timestamp] * len(latarr)
      latarr_total += latarr
      lonarr_total += lonarr
      temparr_total += temparr
      humidityarr_total += humidityarr
      vwindarr_total += vwindarr
      uwindarr_total += uwindarr
      cloud_water_total += preparr


      
      #print(ct)
      
  df["timestamp"]  = ts_total
  df["latitude"] = latarr_total
  df["longitude"] = lonarr_total
  df["temperature"] = temparr_total
  df["humidity"] = humidityarr_total
  df["v_component"] = vwindarr_total
  df["u_component"] = uwindarr_total
  df["precipitation"] = cloud_water_total

  from tabulate import tabulate
  #print(tabulate(df.head(n=5)))

  df.to_csv("2017{}.csv".format(date))
# Out:
# 0701
# 0702
# 0703
# 0704
# 0705
# 0706
# 0707
# 0708
# 0709
# 0710
# 0711
# 0712
# 0713
# 0714
# 0715
# 0716
# 0717
# 0718
# 0719
# 0720
# 0721
# 0722
# 0723
# 0724
# 0725
# 0726
# 0727
# 0728
# 0729
# 0730
# 0731
# 0801
# 0802
# 0803
# 0804
# 0805
# 0806
# 0807
# 0808
# 0809
# 0810
# 0811
# 0812
# 0813
# 0814
# 0815
# 0816
# 0817
# 0818
# 0819
# 0820
# 0821
# 0822
# 0823
# 0824
# 0825
# 0826
# 0827
# 0828
# 0829
# 0830
# 0831
# 0901
# 0902
# 0903
# 0904
# 0905
# 0906
# 0907
# 0908
# 0909
# 0910
# 0911
# 0912
# 0913
# 0914
# 0915
# 0916
# 0917
# 0918
# 0919
# 0920
# 0921
# 0922
# 0923
# 0924
# 0925
# 0926
# 0927
# 0928
# 0929
# 0930

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !zip 2017_julysept.zip *.csv
# Out:
#   adding: 20170701.csv (deflated 74%)
#   adding: 20170702.csv (deflated 74%)
#   adding: 20170703.csv (deflated 74%)
#   adding: 20170704.csv (deflated 74%)
#   adding: 20170705.csv (deflated 74%)
#   adding: 20170706.csv (deflated 74%)
#   adding: 20170707.csv (deflated 74%)
#   adding: 20170708.csv (deflated 75%)
#   adding: 20170709.csv (deflated 75%)
#   adding: 20170710.csv (deflated 74%)
#   adding: 20170711.csv (deflated 74%)
#   adding: 20170712.csv (deflated 74%)
#   adding: 20170713.csv (deflated 75%)
#   adding: 20170714.csv (deflated 74%)
