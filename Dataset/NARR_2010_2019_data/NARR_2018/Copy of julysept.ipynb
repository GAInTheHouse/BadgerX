# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip netCDF4
# Out:
# ERROR: unknown command "netCDF4"

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 95.52G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI458638/'
filelist = [
# 'NARR3D_201805_0103.nc.tar',
# 'NARR3D_201805_0406.nc.tar',
# 'NARR3D_201805_0709.nc.tar',
# 'NARR3D_201805_1012.nc.tar',
# 'NARR3D_201805_1315.nc.tar',
# 'NARR3D_201805_1618.nc.tar',
# 'NARR3D_201805_1921.nc.tar',
# 'NARR3D_201805_2224.nc.tar',
# 'NARR3D_201805_2527.nc.tar',
# 'NARR3D_201805_2831.nc.tar',
# 'NARR3D_201806_0103.nc.tar',
# 'NARR3D_201806_0406.nc.tar',
# 'NARR3D_201806_0709.nc.tar',
# 'NARR3D_201806_1012.nc.tar',
# 'NARR3D_201806_1315.nc.tar',
# 'NARR3D_201806_1618.nc.tar',
# 'NARR3D_201806_1921.nc.tar',
# 'NARR3D_201806_2224.nc.tar',
# 'NARR3D_201806_2527.nc.tar',
# 'NARR3D_201806_2830.nc.tar',
'NARR3D_201807_0103.nc.tar',
'NARR3D_201807_0406.nc.tar',
'NARR3D_201807_0709.nc.tar',
'NARR3D_201807_1012.nc.tar',
'NARR3D_201807_1315.nc.tar',
'NARR3D_201807_1618.nc.tar',
'NARR3D_201807_1921.nc.tar',
'NARR3D_201807_2224.nc.tar',
'NARR3D_201807_2527.nc.tar',
'NARR3D_201807_2831.nc.tar',
'NARR3D_201808_0103.nc.tar',
'NARR3D_201808_0406.nc.tar',
'NARR3D_201808_0709.nc.tar',
'NARR3D_201808_1012.nc.tar',
'NARR3D_201808_1315.nc.tar',
'NARR3D_201808_1618.nc.tar',
'NARR3D_201808_1921.nc.tar',
'NARR3D_201808_2224.nc.tar',
'NARR3D_201808_2527.nc.tar',
'NARR3D_201808_2831.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201807_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201807_2831.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201808_2831.nc.tar
# 100.000 % Completed

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 94.74G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI458640/'
filelist = [
'NARR3D_201809_0103.nc.tar',
'NARR3D_201809_0406.nc.tar',
'NARR3D_201809_0709.nc.tar',
'NARR3D_201809_1012.nc.tar',
'NARR3D_201809_1315.nc.tar',
'NARR3D_201809_1618.nc.tar',
'NARR3D_201809_1921.nc.tar',
'NARR3D_201809_2224.nc.tar',
'NARR3D_201809_2527.nc.tar',
'NARR3D_201809_2830.nc.tar',
# 'NARR3D_201810_0103.nc.tar',
# 'NARR3D_201810_0406.nc.tar',
# 'NARR3D_201810_0709.nc.tar',
# 'NARR3D_201810_1012.nc.tar',
# 'NARR3D_201810_1315.nc.tar',
# 'NARR3D_201810_1618.nc.tar',
# 'NARR3D_201810_1921.nc.tar',
# 'NARR3D_201810_2224.nc.tar',
# 'NARR3D_201810_2527.nc.tar',
# 'NARR3D_201810_2831.nc.tar',
# 'NARR3D_201811_0103.nc.tar',
# 'NARR3D_201811_0406.nc.tar',
# 'NARR3D_201811_0709.nc.tar',
# 'NARR3D_201811_1012.nc.tar',
# 'NARR3D_201811_1315.nc.tar',
# 'NARR3D_201811_1618.nc.tar',
# 'NARR3D_201811_1921.nc.tar',
# 'NARR3D_201811_2224.nc.tar',
# 'NARR3D_201811_2527.nc.tar',
# 'NARR3D_201811_2830.nc.tar',
# 'NARR3D_201812_0103.nc.tar',
# 'NARR3D_201812_0406.nc.tar',
# 'NARR3D_201812_0709.nc.tar',
# 'NARR3D_201812_1012.nc.tar',
# 'NARR3D_201812_1315.nc.tar',
# 'NARR3D_201812_1618.nc.tar',
# 'NARR3D_201812_1921.nc.tar',
# 'NARR3D_201812_2224.nc.tar',
# 'NARR3D_201812_2527.nc.tar',
# 'NARR3D_201812_2831.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201809_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201809_2830.nc.tar
# 100.000 % Completed

# %%
# !pip3 install netcdf4
# Out:
# Collecting netcdf4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 5.2MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netcdf4) (1.18.5)
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 35.1MB/s
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.3.0 netcdf4-1.5.4

# %%
# !mkdir /content/data3

# %%
import os 
import glob 

for f in glob.glob("*.tar"): 
  print(f)
  os.system("tar -xvf  \"//content//{}\" -C /content/data3/".format(f))
  os.system("rm //content//{}".format(f))
# Out:
# NARR3D_201808_1618.nc.tar
# NARR3D_201808_0103.nc.tar
# NARR3D_201808_1315.nc.tar
# NARR3D_201807_1921.nc.tar
# NARR3D_201807_1618.nc.tar
# NARR3D_201808_0709.nc.tar
# NARR3D_201809_1012.nc.tar
# NARR3D_201807_0709.nc.tar
# NARR3D_201807_1012.nc.tar
# NARR3D_201808_0406.nc.tar
# NARR3D_201808_1921.nc.tar
# NARR3D_201809_2830.nc.tar
# NARR3D_201808_2224.nc.tar
# NARR3D_201808_2527.nc.tar
# NARR3D_201807_2224.nc.tar
# NARR3D_201808_2831.nc.tar
# NARR3D_201809_2224.nc.tar
# NARR3D_201808_1012.nc.tar
# NARR3D_201807_2527.nc.tar
# NARR3D_201809_0103.nc.tar
# NARR3D_201807_0103.nc.tar
# NARR3D_201809_1315.nc.tar
# NARR3D_201809_0709.nc.tar
# NARR3D_201809_2527.nc.tar
# NARR3D_201807_0406.nc.tar
# NARR3D_201807_1315.nc.tar
# NARR3D_201809_0406.nc.tar
# NARR3D_201809_1618.nc.tar
# NARR3D_201807_2831.nc.tar
# NARR3D_201809_1921.nc.tar

# %%
mts = ["07", "08", "09"]
mts_days = [31, 31, 30]
dates = []

for i in range(len(mts)):
  dates += [ mts[i] + '{:02d}'.format(j+1) for j in range(mts_days[i])]

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 01:38:08 2020

@author: shreyanssaraogi
"""
from netCDF4 import Dataset
import numpy as np
import pandas as pd

for date in dates: 

  print(date)
  df = pd.DataFrame()
  datafiles = glob.glob('/content/data3/*2018{}*'.format(date))

  if datafiles == []:
    print(date + " is not available.")


  ts_total = []
  latarr_total = []
  lonarr_total = []
  temparr_total =[]
  humidityarr_total =[]
  vwindarr_total = []
  uwindarr_total = []
  cloud_water_total = []


  for j in range(len(datafiles)):
      datafile_name = datafiles[j]
      data = Dataset(datafile_name, 'r')


      # print(data.variables.keys())
      # print(data.variables)
      ct = 0
      latarr= []
      lonarr = []
      temparr =[]
      humidityarr =[]
      vwindarr = []
      uwindarr = []
      preparr= [] 

      
      ct = 0
      i = 0 


      
      
      
      for lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd in zip(data.variables['gridlat_221'][:], data.variables['gridlon_221'][:], data.variables['TMP_221_ISBL'][-1][:],data.variables['SPF_H_221_ISBL'][-1][:], data.variables['V_GRD_221_ISBL'][-1][:], data.variables['U_GRD_221_ISBL'][-1][:],data.variables['CLWMR_221_ISBL'][-1][:]):
          for lat, lon, tmp, hmd, vwind, uwind, prep in zip(lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd): 
              if((lat<43.0) and (lat>33.0) and (lon<-116.0) and (lon>-126.0) ):
                  latarr.append(lat)
                  lonarr.append(lon)
                  temparr.append(tmp)
                  humidityarr.append(hmd)
                  vwindarr.append(vwind)
                  uwindarr.append(uwind)
                  preparr.append(prep)



              ct += 1
              
      timestamp = datafile_name.split(".")[-3]
      #print(timestamp)
      
      ts_total += [timestamp] * len(latarr)
      latarr_total += latarr
      lonarr_total += lonarr
      temparr_total += temparr
      humidityarr_total += humidityarr
      vwindarr_total += vwindarr
      uwindarr_total += uwindarr
      cloud_water_total += preparr


      
      #print(ct)
      
  df["timestamp"]  = ts_total
  df["latitude"] = latarr_total
  df["longitude"] = lonarr_total
  df["temperature"] = temparr_total
  df["humidity"] = humidityarr_total
  df["v_component"] = vwindarr_total
  df["u_component"] = uwindarr_total
  df["precipitation"] = cloud_water_total

  from tabulate import tabulate
  #print(tabulate(df.head(n=5)))

  df.to_csv("2018{}.csv".format(date))
# Out:
# 0701
# 0702
# 0703
# 0704
# 0705
# 0706
# 0707
# 0708
# 0709
# 0710
# 0711
# 0712
# 0713
# 0714
# 0715
# 0716
# 0717
# 0718
# 0719
# 0720
# 0721
# 0722
# 0723
# 0724
# 0725
# 0726
# 0727
# 0728
# 0729
# 0730
# 0731
# 0801
# 0802
# 0803
# 0804
# 0805
# 0806
# 0807
# 0808
# 0809
# 0810
# 0811
# 0812
# 0813
# 0814
# 0815
# 0816
# 0817
# 0818
# 0819
# 0820
# 0821
# 0822
# 0823
# 0824
# 0825
# 0826
# 0827
# 0828
# 0829
# 0830
# 0831
# 0901
# 0902
# 0903
# 0904
# 0905
# 0906
# 0907
# 0908
# 0909
# 0910
# 0911
# 0912
# 0913
# 0914
# 0915
# 0916
# 0917
# 0918
# 0919
# 0920
# 0921
# 0922
# 0923
# 0924
# 0925
# 0926
# 0927
# 0928
# 0929
# 0930

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !zip 2018_julysept.zip *.csv
# Out:
#   adding: 20180701.csv (deflated 75%)
#   adding: 20180702.csv (deflated 75%)
#   adding: 20180703.csv (deflated 75%)
#   adding: 20180704.csv (deflated 75%)
#   adding: 20180705.csv (deflated 74%)
#   adding: 20180706.csv (deflated 74%)
#   adding: 20180707.csv (deflated 75%)
#   adding: 20180708.csv (deflated 75%)
#   adding: 20180709.csv (deflated 74%)
#   adding: 20180710.csv (deflated 75%)
#   adding: 20180711.csv (deflated 74%)
#   adding: 20180712.csv (deflated 74%)
#   adding: 20180713.csv (deflated 75%)
#   adding: 20180714.csv (deflated 75%)
#   adding: 20180715.csv (deflated 75%)
#   adding: 20180716.csv (deflated 74%)
#   adding: 20180717.csv (deflated 75%)
#   adding: 20180718.csv (deflated 74%)
#   adding: 20180719.csv (deflated 74%)
#   adding: 20180720.csv (deflated 74%)
#   adding: 20180721.csv (deflated 75%)
#   adding: 20180722.csv (deflated 74%)
#   adding: 20180723.csv (deflated 75%)
#   adding: 20180724.csv (deflated 75%)
#   adding: 20180725.csv (deflated 74%)
#   adding: 20180726.csv (deflated 74%)
#   adding: 20180727.csv (deflated 74%)
#   adding: 20180728.csv (deflated 75%)
#   adding: 20180729.csv (deflated 74%)
#   adding: 20180730.csv (deflated 74%)
#   adding: 20180731.csv (deflated 74%)
#   adding: 20180801.csv (deflated 74%)
#   adding: 20180802.csv (deflated 75%)
#   adding: 20180803.csv (deflated 74%)
#   adding: 20180804.csv (deflated 74%)
#   adding: 20180805.csv (deflated 74%)
#   adding: 20180806.csv (deflated 75%)
#   adding: 20180807.csv (deflated 75%)
#   adding: 20180808.csv (deflated 75%)
#   adding: 20180809.csv (deflated 74%)
#   adding: 20180810.csv (deflated 75%)
#   adding: 20180811.csv (deflated 75%)
#   adding: 20180812.csv (deflated 75%)
#   adding: 20180813.csv (deflated 75%)
#   adding: 20180814.csv (deflated 75%)
#   adding: 20180815.csv (deflated 75%)
#   adding: 20180816.csv (deflated 75%)
#   adding: 20180817.csv (deflated 75%)
#   adding: 20180818.csv (deflated 74%)
#   adding: 20180819.csv (deflated 75%)
#   adding: 20180820.csv (deflated 74%)
#   adding: 20180821.csv (deflated 74%)
#   adding: 20180822.csv (deflated 75%)
#   adding: 20180823.csv (deflated 75%)
#   adding: 20180824.csv (deflated 75%)
#   adding: 20180825.csv (deflated 74%)
#   adding: 20180826.csv (deflated 74%)
#   adding: 20180827.csv (deflated 75%)
#   adding: 20180828.csv (deflated 75%)
#   adding: 20180829.csv (deflated 75%)
#   adding: 20180830.csv (deflated 75%)
#   adding: 20180831.csv (deflated 74%)
#   adding: 20180901.csv (deflated 75%)
#   adding: 20180902.csv (deflated 75%)
#   adding: 20180903.csv (deflated 74%)
#   adding: 20180904.csv (deflated 75%)
#   adding: 20180905.csv (deflated 75%)
#   adding: 20180906.csv (deflated 75%)
#   adding: 20180907.csv (deflated 75%)
#   adding: 20180908.csv (deflated 74%)
#   adding: 20180909.csv (deflated 74%)
#   adding: 20180910.csv (deflated 74%)
#   adding: 20180911.csv (deflated 74%)
#   adding: 20180912.csv (deflated 75%)
#   adding: 20180913.csv (deflated 75%)
#   adding: 20180914.csv (deflated 75%)
#   adding: 20180915.csv (deflated 75%)
#   adding: 20180916.csv (deflated 75%)
#   adding: 20180917.csv (deflated 74%)
#   adding: 20180918.csv (deflated 74%)
#   adding: 20180919.csv (deflated 75%)
#   adding: 20180920.csv (deflated 76%)
#   adding: 20180921.csv (deflated 75%)
#   adding: 20180922.csv (deflated 75%)
#   adding: 20180923.csv (deflated 75%)
#   adding: 20180924.csv (deflated 75%)
#   adding: 20180925.csv (deflated 74%)
#   adding: 20180926.csv (deflated 75%)
#   adding: 20180927.csv (deflated 75%)
#   adding: 20180928.csv (deflated 75%)
#   adding: 20180929.csv (deflated 75%)
#   adding: 20180930.csv (deflated 75%)

# %%
# !cp 2018_julysept.zip drive/My\ Drive/'BadgerX Data'/NARR_2010_2019_data/NARR_2018
