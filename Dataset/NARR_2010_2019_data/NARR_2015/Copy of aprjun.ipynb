# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# % cd 'NARR_2011'
# %mkdir dowloads_NARR

# %%
# %pwd
# Out:
# '/content'

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 95.52G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI457822/'
filelist = [
'NARR3D_201505_0103.nc.tar',
'NARR3D_201505_0406.nc.tar',
'NARR3D_201505_0709.nc.tar',
'NARR3D_201505_1012.nc.tar',
'NARR3D_201505_1315.nc.tar',
'NARR3D_201505_1618.nc.tar',
'NARR3D_201505_1921.nc.tar',
'NARR3D_201505_2224.nc.tar',
'NARR3D_201505_2527.nc.tar',
'NARR3D_201505_2831.nc.tar',
'NARR3D_201506_0103.nc.tar',
'NARR3D_201506_0406.nc.tar',
'NARR3D_201506_0709.nc.tar',
'NARR3D_201506_1012.nc.tar',
'NARR3D_201506_1315.nc.tar',
'NARR3D_201506_1618.nc.tar',
'NARR3D_201506_1921.nc.tar',
'NARR3D_201506_2224.nc.tar',
'NARR3D_201506_2527.nc.tar',
'NARR3D_201506_2830.nc.tar',
# 'NARR3D_201507_0103.nc.tar',
# 'NARR3D_201507_0406.nc.tar',
# 'NARR3D_201507_0709.nc.tar',
# 'NARR3D_201507_1012.nc.tar',
# 'NARR3D_201507_1315.nc.tar',
# 'NARR3D_201507_1618.nc.tar',
# 'NARR3D_201507_1921.nc.tar',
# 'NARR3D_201507_2224.nc.tar',
# 'NARR3D_201507_2527.nc.tar',
# 'NARR3D_201507_2831.nc.tar',
# 'NARR3D_201508_0103.nc.tar',
# 'NARR3D_201508_0406.nc.tar',
# 'NARR3D_201508_0709.nc.tar',
# 'NARR3D_201508_1012.nc.tar',
# 'NARR3D_201508_1315.nc.tar',
# 'NARR3D_201508_1618.nc.tar',
# 'NARR3D_201508_1921.nc.tar',
# 'NARR3D_201508_2224.nc.tar',
# 'NARR3D_201508_2527.nc.tar',
# 'NARR3D_201508_2831.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 93.19G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI457821/'
filelist = [
# 'NARR3D_201501_0103.nc.tar',
# 'NARR3D_201501_0406.nc.tar',
# 'NARR3D_201501_0709.nc.tar',
# 'NARR3D_201501_1012.nc.tar',
# 'NARR3D_201501_1315.nc.tar',
# 'NARR3D_201501_1618.nc.tar',
# 'NARR3D_201501_1921.nc.tar',
# 'NARR3D_201501_2224.nc.tar',
# 'NARR3D_201501_2527.nc.tar',
# 'NARR3D_201501_2831.nc.tar',
# 'NARR3D_201502_0103.nc.tar',
# 'NARR3D_201502_0406.nc.tar',
# 'NARR3D_201502_0709.nc.tar',
# 'NARR3D_201502_1012.nc.tar',
# 'NARR3D_201502_1315.nc.tar',
# 'NARR3D_201502_1618.nc.tar',
# 'NARR3D_201502_1921.nc.tar',
# 'NARR3D_201502_2224.nc.tar',
# 'NARR3D_201502_2527.nc.tar',
# 'NARR3D_201502_2828.nc.tar',
# 'NARR3D_201503_0103.nc.tar',
# 'NARR3D_201503_0406.nc.tar',
# 'NARR3D_201503_0709.nc.tar',
# 'NARR3D_201503_1012.nc.tar',
# 'NARR3D_201503_1315.nc.tar',
# 'NARR3D_201503_1618.nc.tar',
# 'NARR3D_201503_1921.nc.tar',
# 'NARR3D_201503_2224.nc.tar',
# 'NARR3D_201503_2527.nc.tar',
# 'NARR3D_201503_2831.nc.tar',
'NARR3D_201504_0103.nc.tar',
'NARR3D_201504_0406.nc.tar',
'NARR3D_201504_0709.nc.tar',
'NARR3D_201504_1012.nc.tar',
'NARR3D_201504_1315.nc.tar',
'NARR3D_201504_1618.nc.tar',
'NARR3D_201504_1921.nc.tar',
'NARR3D_201504_2224.nc.tar',
'NARR3D_201504_2527.nc.tar',
'NARR3D_201504_2830.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed
# ...
# 100.000 % Completed

# %%
# !pip3 install netcdf4
# Out:
# ...
#      |████████████████████████████████| 4.3MB 7.0MB/s
# ...
#      |████████████████████████████████| 296kB 33.8MB/s
# ...

# %%
# !mkdir /content/data3
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
import glob 

for f in glob.glob("*.tar"): 
  print(f)
  os.system("tar -xvf  \"//content//{}\" -C /content/data3/".format(f))
  os.system("rm //content//{}".format(f))
# Out:
# NARR3D_201504_1012.nc.tar
# NARR3D_201506_2224.nc.tar
# NARR3D_201504_1921.nc.tar
# NARR3D_201506_0406.nc.tar
# NARR3D_201506_1315.nc.tar
# NARR3D_201504_2224.nc.tar
# NARR3D_201505_1315.nc.tar
# NARR3D_201506_2830.nc.tar
# NARR3D_201505_0406.nc.tar
# NARR3D_201506_2527.nc.tar
# NARR3D_201506_0709.nc.tar
# NARR3D_201505_2527.nc.tar
# NARR3D_201505_1921.nc.tar
# NARR3D_201504_2527.nc.tar
# NARR3D_201506_0103.nc.tar
# NARR3D_201504_2830.nc.tar
# NARR3D_201505_0709.nc.tar
# NARR3D_201505_1012.nc.tar
# NARR3D_201506_1012.nc.tar
# NARR3D_201504_1618.nc.tar
# NARR3D_201504_1315.nc.tar
# NARR3D_201505_0103.nc.tar
# NARR3D_201504_0709.nc.tar
# NARR3D_201506_1618.nc.tar
# NARR3D_201505_1618.nc.tar
# NARR3D_201504_0406.nc.tar
# NARR3D_201505_2224.nc.tar
# NARR3D_201506_1921.nc.tar
# NARR3D_201505_2831.nc.tar
# NARR3D_201504_0103.nc.tar

# %%
mts = ["04", "05", "06"]
mts_days = [30, 31 , 30]
dates = []

for i in range(len(mts)):
  dates += [ mts[i] + '{:02d}'.format(j+1) for j in range(mts_days[i])]

# %%
! pip netCDF4
# Out:
# ERROR: unknown command "netCDF4"

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 01:38:08 2020

@author: shreyanssaraogi
"""
from netCDF4 import Dataset
import numpy as np
import pandas as pd

for date in dates: 

  print(date)
  df = pd.DataFrame()
  datafiles = glob.glob('/content/data3/*2015{}*'.format(date))

  if datafiles == []:
    print(date + " is not available.")


  ts_total = []
  latarr_total = []
  lonarr_total = []
  temparr_total =[]
  humidityarr_total =[]
  vwindarr_total = []
  uwindarr_total = []
  cloud_water_total = []


  for j in range(len(datafiles)):
      datafile_name = datafiles[j]
      data = Dataset(datafile_name, 'r')


      # print(data.variables.keys())
      # print(data.variables)
      ct = 0
      latarr= []
      lonarr = []
      temparr =[]
      humidityarr =[]
      vwindarr = []
      uwindarr = []
      preparr= [] 

      
      ct = 0
      i = 0 


      
      
      
      for lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd in zip(data.variables['gridlat_221'][:], data.variables['gridlon_221'][:], data.variables['TMP_221_ISBL'][-1][:],data.variables['SPF_H_221_ISBL'][-1][:], data.variables['V_GRD_221_ISBL'][-1][:], data.variables['U_GRD_221_ISBL'][-1][:],data.variables['CLWMR_221_ISBL'][-1][:]):
          for lat, lon, tmp, hmd, vwind, uwind, prep in zip(lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd): 
              if((lat<43.0) and (lat>33.0) and (lon<-116.0) and (lon>-126.0) ):
                  latarr.append(lat)
                  lonarr.append(lon)
                  temparr.append(tmp)
                  humidityarr.append(hmd)
                  vwindarr.append(vwind)
                  uwindarr.append(uwind)
                  preparr.append(prep)



              ct += 1
              
      timestamp = datafile_name.split(".")[-3]
      #print(timestamp)
      
      ts_total += [timestamp] * len(latarr)
      latarr_total += latarr
      lonarr_total += lonarr
      temparr_total += temparr
      humidityarr_total += humidityarr
      vwindarr_total += vwindarr
      uwindarr_total += uwindarr
      cloud_water_total += preparr


      
      #print(ct)
      
  df["timestamp"]  = ts_total
  df["latitude"] = latarr_total
  df["longitude"] = lonarr_total
  df["temperature"] = temparr_total
  df["humidity"] = humidityarr_total
  df["v_component"] = vwindarr_total
  df["u_component"] = uwindarr_total
  df["precipitation"] = cloud_water_total

  from tabulate import tabulate
  #print(tabulate(df.head(n=5)))

  df.to_csv("2011{}.csv".format(date))

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !zip 2015_aprjun.zip *.csv

# %%
# !cp 2015_aprjun.zip drive/My\ Drive/'BadgerX Data'/NARR_2010_2019_data/NARR_2015
