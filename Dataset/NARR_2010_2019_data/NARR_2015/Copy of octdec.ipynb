# %%
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install netcdf4
# Out:
# Collecting netcdf4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 6.4MB/s
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 31.4MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netcdf4) (1.18.5)
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.3.0 netcdf4-1.5.4

# %%
# !mkdir /content/data3

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 94.74G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI457824/'
filelist = [
# 'NARR3D_201509_0103.nc.tar',
# 'NARR3D_201509_0406.nc.tar',
# 'NARR3D_201509_0709.nc.tar',
# 'NARR3D_201509_1012.nc.tar',
# 'NARR3D_201509_1315.nc.tar',
# 'NARR3D_201509_1618.nc.tar',
# 'NARR3D_201509_1921.nc.tar',
# 'NARR3D_201509_2224.nc.tar',
# 'NARR3D_201509_2527.nc.tar',
# 'NARR3D_201509_2830.nc.tar',
'NARR3D_201510_0103.nc.tar',
'NARR3D_201510_0406.nc.tar',
'NARR3D_201510_0709.nc.tar',
'NARR3D_201510_1012.nc.tar',
'NARR3D_201510_1315.nc.tar',
'NARR3D_201510_1618.nc.tar',
'NARR3D_201510_1921.nc.tar',
'NARR3D_201510_2224.nc.tar',
'NARR3D_201510_2527.nc.tar',
'NARR3D_201510_2831.nc.tar',
'NARR3D_201511_0103.nc.tar',
'NARR3D_201511_0406.nc.tar',
'NARR3D_201511_0709.nc.tar',
'NARR3D_201511_1012.nc.tar',
'NARR3D_201511_1315.nc.tar',
'NARR3D_201511_1618.nc.tar',
'NARR3D_201511_1921.nc.tar',
'NARR3D_201511_2224.nc.tar',
'NARR3D_201511_2527.nc.tar',
'NARR3D_201511_2830.nc.tar',
'NARR3D_201512_0103.nc.tar',
'NARR3D_201512_0406.nc.tar',
'NARR3D_201512_0709.nc.tar',
'NARR3D_201512_1012.nc.tar',
'NARR3D_201512_1315.nc.tar',
'NARR3D_201512_1618.nc.tar',
'NARR3D_201512_1921.nc.tar',
'NARR3D_201512_2224.nc.tar',
'NARR3D_201512_2527.nc.tar',
'NARR3D_201512_2831.nc.tar']
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201510_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201510_2831.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201511_2830.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201512_2831.nc.tar
# 100.000 % Completed

# %%
import os 
import glob 

for f in glob.glob("*.tar"): 
  print(f)
  os.system("tar -xvf  \"//content//{}\" -C /content/data3/".format(f))
  os.system("rm //content//{}".format(f))
# Out:
# NARR3D_201510_2224.nc.tar
# NARR3D_201512_1921.nc.tar
# NARR3D_201510_0406.nc.tar
# NARR3D_201510_2527.nc.tar
# NARR3D_201511_2830.nc.tar
# NARR3D_201512_1618.nc.tar
# NARR3D_201512_1012.nc.tar
# NARR3D_201511_1618.nc.tar
# NARR3D_201511_1012.nc.tar
# NARR3D_201511_2224.nc.tar
# NARR3D_201512_0709.nc.tar
# NARR3D_201510_0103.nc.tar
# NARR3D_201512_2224.nc.tar
# NARR3D_201512_0406.nc.tar
# NARR3D_201510_2831.nc.tar
# NARR3D_201510_1618.nc.tar
# NARR3D_201511_1315.nc.tar
# NARR3D_201512_2831.nc.tar
# NARR3D_201512_1315.nc.tar
# NARR3D_201511_0406.nc.tar
# NARR3D_201511_0103.nc.tar
# NARR3D_201510_1012.nc.tar
# NARR3D_201511_1921.nc.tar
# NARR3D_201510_0709.nc.tar
# NARR3D_201511_2527.nc.tar
# NARR3D_201510_1921.nc.tar
# NARR3D_201511_0709.nc.tar
# NARR3D_201512_2527.nc.tar
# NARR3D_201510_1315.nc.tar
# NARR3D_201512_0103.nc.tar

# %%
mts = ["10", "11", "12"]
mts_days = [31, 30, 31]
dates = []

for i in range(len(mts)):
  dates += [ mts[i] + '{:02d}'.format(j+1) for j in range(mts_days[i])]

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 01:38:08 2020

@author: shreyanssaraogi
"""
from netCDF4 import Dataset
import numpy as np
import pandas as pd

for date in dates: 

  print(date)
  df = pd.DataFrame()
  datafiles = glob.glob('/content/data3/*2015{}*'.format(date))

  if datafiles == []:
    print(date + " is not available.")


  ts_total = []
  latarr_total = []
  lonarr_total = []
  temparr_total =[]
  humidityarr_total =[]
  vwindarr_total = []
  uwindarr_total = []
  cloud_water_total = []


  for j in range(len(datafiles)):
      datafile_name = datafiles[j]
      data = Dataset(datafile_name, 'r')


      # print(data.variables.keys())
      # print(data.variables)
      ct = 0
      latarr= []
      lonarr = []
      temparr =[]
      humidityarr =[]
      vwindarr = []
      uwindarr = []
      preparr= [] 

      
      ct = 0
      i = 0 


      
      
      
      for lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd in zip(data.variables['gridlat_221'][:], data.variables['gridlon_221'][:], data.variables['TMP_221_ISBL'][-1][:],data.variables['SPF_H_221_ISBL'][-1][:], data.variables['V_GRD_221_ISBL'][-1][:], data.variables['U_GRD_221_ISBL'][-1][:],data.variables['CLWMR_221_ISBL'][-1][:]):
          for lat, lon, tmp, hmd, vwind, uwind, prep in zip(lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd): 
              if((lat<43.0) and (lat>33.0) and (lon<-116.0) and (lon>-126.0) ):
                  latarr.append(lat)
                  lonarr.append(lon)
                  temparr.append(tmp)
                  humidityarr.append(hmd)
                  vwindarr.append(vwind)
                  uwindarr.append(uwind)
                  preparr.append(prep)



              ct += 1
              
      timestamp = datafile_name.split(".")[-3]
      #print(timestamp)
      
      ts_total += [timestamp] * len(latarr)
      latarr_total += latarr
      lonarr_total += lonarr
      temparr_total += temparr
      humidityarr_total += humidityarr
      vwindarr_total += vwindarr
      uwindarr_total += uwindarr
      cloud_water_total += preparr


      
      #print(ct)
      
  df["timestamp"]  = ts_total
  df["latitude"] = latarr_total
  df["longitude"] = lonarr_total
  df["temperature"] = temparr_total
  df["humidity"] = humidityarr_total
  df["v_component"] = vwindarr_total
  df["u_component"] = uwindarr_total
  df["precipitation"] = cloud_water_total

  from tabulate import tabulate
  #print(tabulate(df.head(n=5)))

  df.to_csv("2015{}.csv".format(date))
# Out:
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1201
# 1202
# 1203
# 1204
# 1205
# 1206
# 1207
# 1208
# 1209
# 1210
# 1211
# 1212
# 1213
# 1214
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1221
# 1222
# 1223
# 1224
# 1225
# 1226
# 1227
# 1228
# 1229
# 1230
# 1231

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !zip 2015_octdec.zip *.csv
# Out:
#   adding: 20151001.csv (deflated 74%)
#   adding: 20151002.csv (deflated 74%)
#   adding: 20151003.csv (deflated 75%)
#   adding: 20151004.csv (deflated 76%)
#   adding: 20151005.csv (deflated 76%)
#   adding: 20151006.csv (deflated 75%)
#   adding: 20151007.csv (deflated 74%)
#   adding: 20151008.csv (deflated 74%)
#   adding: 20151009.csv (deflated 75%)
#   adding: 20151010.csv (deflated 75%)
#   adding: 20151011.csv (deflated 75%)
#   adding: 20151012.csv (deflated 76%)
#   adding: 20151013.csv (deflated 76%)
#   adding: 20151014.csv (deflated 75%)
#   adding: 20151015.csv (deflated 75%)
#   adding: 20151016.csv (deflated 75%)
#   adding: 20151017.csv (deflated 74%)
#   adding: 20151018.csv (deflated 75%)
#   adding: 20151019.csv (deflated 75%)
#   adding: 20151020.csv (deflated 75%)
#   adding: 20151021.csv (deflated 74%)
#   adding: 20151022.csv (deflated 74%)
#   adding: 20151023.csv (deflated 74%)
