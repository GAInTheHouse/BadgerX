# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# % cd 'NARR_2010'
# %mkdir dowloads_NARR

# %%
# %pwd
# Out:
# '/content'

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 40 online Data files of 'ds608.0',
# total 93.19G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI458641/'
filelist = [
'NARR3D_201901_0103.nc.tar',
'NARR3D_201901_0406.nc.tar',
'NARR3D_201901_0709.nc.tar',
'NARR3D_201901_1012.nc.tar',
'NARR3D_201901_1315.nc.tar',
'NARR3D_201901_1618.nc.tar',
'NARR3D_201901_1921.nc.tar',
'NARR3D_201901_2224.nc.tar',
'NARR3D_201901_2527.nc.tar',
'NARR3D_201901_2831.nc.tar',
'NARR3D_201902_0103.nc.tar',
'NARR3D_201902_0406.nc.tar',
'NARR3D_201902_0709.nc.tar',
'NARR3D_201902_1012.nc.tar',
'NARR3D_201902_1315.nc.tar',
'NARR3D_201902_1618.nc.tar',
'NARR3D_201902_1921.nc.tar',
'NARR3D_201902_2224.nc.tar',
'NARR3D_201902_2527.nc.tar',
'NARR3D_201902_2828.nc.tar',
'NARR3D_201903_0103.nc.tar',
'NARR3D_201903_0406.nc.tar',
'NARR3D_201903_0709.nc.tar',
'NARR3D_201903_1012.nc.tar',
'NARR3D_201903_1315.nc.tar',
'NARR3D_201903_1618.nc.tar',
'NARR3D_201903_1921.nc.tar',
'NARR3D_201903_2224.nc.tar',
'NARR3D_201903_2527.nc.tar',
'NARR3D_201903_2831.nc.tar',
# 'NARR3D_201904_0103.nc.tar',
# 'NARR3D_201904_0406.nc.tar',
# 'NARR3D_201904_0709.nc.tar',
# 'NARR3D_201904_1012.nc.tar',
# 'NARR3D_201904_1315.nc.tar',
# 'NARR3D_201904_1618.nc.tar',
# 'NARR3D_201904_1921.nc.tar',
# 'NARR3D_201904_2224.nc.tar',
# 'NARR3D_201904_2527.nc.tar',
# 'NARR3D_201904_2830.nc.tar'
]
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201901_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201901_2831.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201902_2828.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201903_2831.nc.tar
# 100.000 % Completed

# %%
# !pip3 install netcdf4
# Out:
# Collecting netcdf4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 5.6MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netcdf4) (1.18.5)
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 40.9MB/s
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.3.0 netcdf4-1.5.4

# %%
# !mkdir /content/data3

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
import glob 

for f in glob.glob("*.tar"): 
  print(f)
  os.system("tar -xvf  \"//content//{}\" -C /content/data3/".format(f))
  os.system("rm //content//{}".format(f))
# Out:
# NARR3D_201901_0103.nc.tar
# NARR3D_201903_1618.nc.tar
# NARR3D_201903_0709.nc.tar
# NARR3D_201902_0103.nc.tar
# NARR3D_201902_1012.nc.tar
# NARR3D_201902_1618.nc.tar
# NARR3D_201901_2527.nc.tar
# NARR3D_201901_2224.nc.tar
# NARR3D_201903_2527.nc.tar
# NARR3D_201901_1315.nc.tar
# NARR3D_201903_1315.nc.tar
# NARR3D_201903_1921.nc.tar
# NARR3D_201903_1012.nc.tar
# NARR3D_201901_1618.nc.tar
# NARR3D_201901_0709.nc.tar
# NARR3D_201901_1921.nc.tar
# NARR3D_201901_2831.nc.tar
# NARR3D_201903_0103.nc.tar
# NARR3D_201902_2828.nc.tar
# NARR3D_201902_2527.nc.tar
# NARR3D_201903_2224.nc.tar
# NARR3D_201902_1921.nc.tar
# NARR3D_201903_2831.nc.tar
# NARR3D_201901_1012.nc.tar
# NARR3D_201902_1315.nc.tar
# NARR3D_201901_0406.nc.tar
# NARR3D_201902_0709.nc.tar
# NARR3D_201903_0406.nc.tar
# NARR3D_201902_0406.nc.tar
# NARR3D_201902_2224.nc.tar

# %%
mts = ["01", "02", "03"]
mts_days = [31, 28, 31]
dates = []

for i in range(len(mts)):
  dates += [ mts[i] + '{:02d}'.format(j+1) for j in range(mts_days[i])]

# %%
! pip netCDF4
# Out:
# ERROR: unknown command "netCDF4"

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 01:38:08 2020

@author: shreyanssaraogi
"""
from netCDF4 import Dataset
import numpy as np
import pandas as pd

for date in dates: 

  print(date)
  df = pd.DataFrame()
  datafiles = glob.glob('/content/data3/*2019{}*'.format(date))

  if datafiles == []:
    print(date + " is not available.")


  ts_total = []
  latarr_total = []
  lonarr_total = []
  temparr_total =[]
  humidityarr_total =[]
  vwindarr_total = []
  uwindarr_total = []
  cloud_water_total = []


  for j in range(len(datafiles)):
      datafile_name = datafiles[j]
      data = Dataset(datafile_name, 'r')


      # print(data.variables.keys())
      # print(data.variables)
      ct = 0
      latarr= []
      lonarr = []
      temparr =[]
      humidityarr =[]
      vwindarr = []
      uwindarr = []
      preparr= [] 

      
      ct = 0
      i = 0 


      
      
      
      for lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd in zip(data.variables['gridlat_221'][:], data.variables['gridlon_221'][:], data.variables['TMP_221_ISBL'][-1][:],data.variables['SPF_H_221_ISBL'][-1][:], data.variables['V_GRD_221_ISBL'][-1][:], data.variables['U_GRD_221_ISBL'][-1][:],data.variables['CLWMR_221_ISBL'][-1][:]):
          for lat, lon, tmp, hmd, vwind, uwind, prep in zip(lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd): 
              if((lat<43.0) and (lat>33.0) and (lon<-116.0) and (lon>-126.0) ):
                  latarr.append(lat)
                  lonarr.append(lon)
                  temparr.append(tmp)
                  humidityarr.append(hmd)
                  vwindarr.append(vwind)
                  uwindarr.append(uwind)
                  preparr.append(prep)



              ct += 1
              
      timestamp = datafile_name.split(".")[-3]
      #print(timestamp)
      
      ts_total += [timestamp] * len(latarr)
      latarr_total += latarr
      lonarr_total += lonarr
      temparr_total += temparr
      humidityarr_total += humidityarr
      vwindarr_total += vwindarr
      uwindarr_total += uwindarr
      cloud_water_total += preparr


      
      #print(ct)
      
  df["timestamp"]  = ts_total
  df["latitude"] = latarr_total
  df["longitude"] = lonarr_total
  df["temperature"] = temparr_total
  df["humidity"] = humidityarr_total
  df["v_component"] = vwindarr_total
  df["u_component"] = uwindarr_total
  df["precipitation"] = cloud_water_total

  from tabulate import tabulate
  #print(tabulate(df.head(n=5)))

  df.to_csv("2019{}.csv".format(date))
# Out:
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0201
# 0202
# 0203
# 0204
# 0205
# 0206
# 0207
# 0208
# 0209
# 0210
# 0211
# 0212
# 0213
# 0214
# 0215
# 0216
# 0217
# 0218
# 0219
# 0220
# 0221
# 0222
# 0223
# 0224
# 0225
# 0226
# 0227
# 0228
# 0301
# 0302
# 0303
# 0304
# 0305
# 0306
# 0307
# 0308
# 0309
# 0310
# 0311
# 0312
# 0313
# 0314
# 0315
# 0316
# 0317
# 0318
# 0319
# 0320
# 0321
# 0322
# 0323
# 0324
# 0325
# 0326
# 0327
# 0328
# 0329
# 0330
# 0331

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !zip 2019_jan_apr.zip *.csv
# Out:
#   adding: 20190101.csv (deflated 76%)
#   adding: 20190102.csv (deflated 76%)
#   adding: 20190103.csv (deflated 76%)
#   adding: 20190104.csv (deflated 75%)
#   adding: 20190105.csv (deflated 76%)
#   adding: 20190106.csv (deflated 77%)
#   adding: 20190107.csv (deflated 75%)
#   adding: 20190108.csv (deflated 75%)
#   adding: 20190109.csv (deflated 75%)
#   adding: 20190110.csv (deflated 76%)
#   adding: 20190111.csv (deflated 76%)
#   adding: 20190112.csv (deflated 76%)
#   adding: 20190113.csv (deflated 76%)
#   adding: 20190114.csv (deflated 77%)
#   adding: 20190115.csv (deflated 77%)
#   adding: 20190116.csv (deflated 76%)
#   adding: 20190117.csv (deflated 76%)
#   adding: 20190118.csv (deflated 76%)
#   adding: 20190119.csv (deflated 75%)
#   adding: 20190120.csv (deflated 75%)
#   adding: 20190121.csv (deflated 77%)
#   adding: 20190122.csv (deflated 77%)
#   adding: 20190123.csv (deflated 76%)
#   adding: 20190124.csv (deflated 76%)
#   adding: 20190125.csv (deflated 75%)
#   adding: 20190126.csv (deflated 76%)
#   adding: 20190127.csv (deflated 77%)
#   adding: 20190128.csv (deflated 76%)
#   adding: 20190129.csv (deflated 76%)
#   adding: 20190130.csv (deflated 75%)
#   adding: 20190131.csv (deflated 75%)
#   adding: 20190201.csv (deflated 75%)
#   adding: 20190202.csv (deflated 76%)
#   adding: 20190203.csv (deflated 77%)
#   adding: 20190204.csv (deflated 77%)
#   adding: 20190205.csv (deflated 77%)
#   adding: 20190206.csv (deflated 77%)
#   adding: 20190207.csv (deflated 76%)
#   adding: 20190208.csv (deflated 76%)
#   adding: 20190209.csv (deflated 77%)
#   adding: 20190210.csv (deflated 77%)
#   adding: 20190211.csv (deflated 77%)
#   adding: 20190212.csv (deflated 76%)
#   adding: 20190213.csv (deflated 75%)
#   adding: 20190214.csv (deflated 75%)
#   adding: 20190215.csv (deflated 77%)
#   adding: 20190216.csv (deflated 77%)
#   adding: 20190217.csv (deflated 77%)
#   adding: 20190218.csv (deflated 77%)
#   adding: 20190219.csv (deflated 77%)
#   adding: 20190220.csv (deflated 76%)
#   adding: 20190221.csv (deflated 77%)
#   adding: 20190222.csv (deflated 77%)
#   adding: 20190223.csv (deflated 77%)
#   adding: 20190224.csv (deflated 76%)
#   adding: 20190225.csv (deflated 76%)
#   adding: 20190226.csv (deflated 75%)
#   adding: 20190227.csv (deflated 75%)
#   adding: 20190228.csv (deflated 76%)
#   adding: 20190301.csv (deflated 76%)
#   adding: 20190302.csv (deflated 75%)
#   adding: 20190303.csv (deflated 75%)
#   adding: 20190304.csv (deflated 76%)
#   adding: 20190305.csv (deflated 76%)
#   adding: 20190306.csv (deflated 76%)
#   adding: 20190307.csv (deflated 77%)
#   adding: 20190308.csv (deflated 77%)
#   adding: 20190309.csv (deflated 77%)
#   adding: 20190310.csv (deflated 77%)
#   adding: 20190311.csv (deflated 77%)
#   adding: 20190312.csv (deflated 76%)
#   adding: 20190313.csv (deflated 77%)
#   adding: 20190314.csv (deflated 77%)
#   adding: 20190315.csv (deflated 76%)
#   adding: 20190316.csv (deflated 76%)
#   adding: 20190317.csv (deflated 76%)
#   adding: 20190318.csv (deflated 76%)
#   adding: 20190319.csv (deflated 75%)
#   adding: 20190320.csv (deflated 76%)
#   adding: 20190321.csv (deflated 76%)
#   adding: 20190322.csv (deflated 75%)
#   adding: 20190323.csv (deflated 76%)
#   adding: 20190324.csv (deflated 76%)
#   adding: 20190325.csv (deflated 75%)
#   adding: 20190326.csv (deflated 76%)
#   adding: 20190327.csv (deflated 76%)
#   adding: 20190328.csv (deflated 77%)
#   adding: 20190329.csv (deflated 77%)
#   adding: 20190330.csv (deflated 76%)
#   adding: 20190331.csv (deflated 75%)

# %%
# !cp 2019_jan_apr.zip drive/My\ Drive/'BadgerX Data'/NARR_2010_2019_data/NARR_2019

# %%
# !rm *.csv
