# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# % cd 'NARR_2010'
# %mkdir dowloads_NARR
# Out:
# mkdir: cannot create directory ‘dowloads_NARR’: File exists

# %%
# %pwd
# Out:
# '/content'

# %%
#!/usr/bin/env python
#################################################################
# Python Script to retrieve 30 online Data files of 'ds608.0',
# total 70.67G. This script uses 'requests' to download data.
#
# Highlight this script by Select All, Copy and Paste it into a file;
# make the file executable and run it on command line.
#
# You need pass in your password as a parameter to execute
# this script; or you can set an environment variable RDAPSWD
# if your Operating System supports it.
#
# Contact chifan@ucar.edu (Chi-Fan Shih) for further assistance.
#################################################################


import sys, os
import requests

def check_file_status(filepath, filesize):
    sys.stdout.write('\r')
    sys.stdout.flush()
    size = int(os.stat(filepath).st_size)
    percent_complete = (size/filesize)*100
    sys.stdout.write('%.3f %s' % (percent_complete, '% Completed'))
    sys.stdout.flush()

# Try to get password
if len(sys.argv) < 2 and not 'RDAPSWD' in os.environ:
    try:
        import getpass
        input = getpass.getpass
    except:
        try:
            input = raw_input
        except:
            pass
    pswd = input('Password: ')
else:
    try:
        pswd = sys.argv[1]
    except:
        pswd = os.environ['RDAPSWD']

url = 'https://rda.ucar.edu/cgi-bin/login'
values = {'email' : 'saraogi@wisc.edu', 'passwd' : '123Shreyans', 'action' : 'login'}
# Authenticate
ret = requests.post(url,data=values)
if ret.status_code != 200:
    print('Bad Authentication')
    print(ret.text)
    exit(1)
dspath = 'https://rda.ucar.edu/dsrqst/SARAOGI458703/'
filelist = [
'NARR3D_201601_0103.nc.tar',
'NARR3D_201601_0406.nc.tar',
'NARR3D_201601_0709.nc.tar',
'NARR3D_201601_1012.nc.tar',
'NARR3D_201601_1315.nc.tar',
'NARR3D_201601_1618.nc.tar',
'NARR3D_201601_1921.nc.tar',
'NARR3D_201601_2224.nc.tar',
'NARR3D_201601_2527.nc.tar',
'NARR3D_201601_2831.nc.tar',
'NARR3D_201602_0103.nc.tar',
'NARR3D_201602_0406.nc.tar',
'NARR3D_201602_0709.nc.tar',
'NARR3D_201602_1012.nc.tar',
'NARR3D_201602_1315.nc.tar',
'NARR3D_201602_1618.nc.tar',
'NARR3D_201602_1921.nc.tar',
'NARR3D_201602_2224.nc.tar',
'NARR3D_201602_2527.nc.tar',
'NARR3D_201602_2829.nc.tar',
'NARR3D_201603_0103.nc.tar',
'NARR3D_201603_0406.nc.tar',
'NARR3D_201603_0709.nc.tar',
'NARR3D_201603_1012.nc.tar',
'NARR3D_201603_1315.nc.tar',
'NARR3D_201603_1618.nc.tar',
'NARR3D_201603_1921.nc.tar',
'NARR3D_201603_2224.nc.tar',
'NARR3D_201603_2527.nc.tar',
'NARR3D_201603_2831.nc.tar']
for file in filelist:
    filename=dspath+file
    file_base = os.path.basename(file)
    print('Downloading',file_base)
    req = requests.get(filename, cookies = ret.cookies, allow_redirects=True, stream=True)
    filesize = int(req.headers['Content-length'])
    with open(file_base, 'wb') as outfile:
        chunk_size=1048576
        for chunk in req.iter_content(chunk_size=chunk_size):
            outfile.write(chunk)
            if chunk_size < filesize:
                check_file_status(file_base, filesize)
    check_file_status(file_base, filesize)
    print()
# Out:
# Downloading NARR3D_201601_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201601_2831.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201602_2829.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_0103.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_0406.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_0709.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_1012.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_1315.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_1618.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_1921.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_2224.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_2527.nc.tar
# 100.000 % Completed
# Downloading NARR3D_201603_2831.nc.tar
# 100.000 % Completed

# %%
# !pip3 install netcdf4
# Out:
# Collecting netcdf4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 5.7MB/s
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 40.4MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netcdf4) (1.18.5)
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.3.0 netcdf4-1.5.4

# %%
# !mkdir /content/data3

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
import glob 

for f in glob.glob("*.tar"): 
  print(f)
  os.system("tar -xvf  \"//content//{}\" -C /content/data3/".format(f))
  os.system("rm //content//{}".format(f))
# Out:
# NARR3D_201603_1315.nc.tar
# NARR3D_201603_2224.nc.tar
# NARR3D_201602_1315.nc.tar
# NARR3D_201601_2224.nc.tar
# NARR3D_201601_1012.nc.tar
# NARR3D_201601_2831.nc.tar
# NARR3D_201602_2527.nc.tar
# NARR3D_201601_0406.nc.tar
# NARR3D_201601_0103.nc.tar
# NARR3D_201602_0103.nc.tar
# NARR3D_201602_0709.nc.tar
# NARR3D_201602_1618.nc.tar
# NARR3D_201602_0406.nc.tar
# NARR3D_201601_0709.nc.tar
# NARR3D_201603_2527.nc.tar
# NARR3D_201603_1012.nc.tar
# NARR3D_201602_2829.nc.tar
# NARR3D_201601_1315.nc.tar
# NARR3D_201601_2527.nc.tar
# NARR3D_201602_1012.nc.tar
# NARR3D_201602_1921.nc.tar
# NARR3D_201601_1921.nc.tar
# NARR3D_201603_0406.nc.tar
# NARR3D_201603_0103.nc.tar
# NARR3D_201602_2224.nc.tar
# NARR3D_201603_0709.nc.tar
# NARR3D_201601_1618.nc.tar
# NARR3D_201603_1618.nc.tar
# NARR3D_201603_1921.nc.tar
# NARR3D_201603_2831.nc.tar

# %%
mts = ["01", "02", "03"]
mts_days = [31, 29, 31]
dates = []

for i in range(len(mts)):
  dates += [ mts[i] + '{:02d}'.format(j+1) for j in range(mts_days[i])]

# %%
! pip netCDF4
# Out:
# ERROR: unknown command "netCDF4"

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 01:38:08 2020

@author: shreyanssaraogi
"""
from netCDF4 import Dataset
import numpy as np
import pandas as pd

for date in dates: 

  print(date)
  df = pd.DataFrame()
  datafiles = glob.glob('/content/data3/*2016{}*'.format(date))

  if datafiles == []:
    print(date + " is not available.")


  ts_total = []
  latarr_total = []
  lonarr_total = []
  temparr_total =[]
  humidityarr_total =[]
  vwindarr_total = []
  uwindarr_total = []
  cloud_water_total = []


  for j in range(len(datafiles)):
      datafile_name = datafiles[j]
      data = Dataset(datafile_name, 'r')


      # print(data.variables.keys())
      # print(data.variables)
      ct = 0
      latarr= []
      lonarr = []
      temparr =[]
      humidityarr =[]
      vwindarr = []
      uwindarr = []
      preparr= [] 

      
      ct = 0
      i = 0 


      
      
      
      for lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd in zip(data.variables['gridlat_221'][:], data.variables['gridlon_221'][:], data.variables['TMP_221_ISBL'][-1][:],data.variables['SPF_H_221_ISBL'][-1][:], data.variables['V_GRD_221_ISBL'][-1][:], data.variables['U_GRD_221_ISBL'][-1][:],data.variables['CLWMR_221_ISBL'][-1][:]):
          for lat, lon, tmp, hmd, vwind, uwind, prep in zip(lat_grd, lon_grd, temp_grd, hmd_grd, v_grd, u_grd, prep_grd): 
              if((lat<43.0) and (lat>33.0) and (lon<-116.0) and (lon>-126.0) ):
                  latarr.append(lat)
                  lonarr.append(lon)
                  temparr.append(tmp)
                  humidityarr.append(hmd)
                  vwindarr.append(vwind)
                  uwindarr.append(uwind)
                  preparr.append(prep)



              ct += 1
              
      timestamp = datafile_name.split(".")[-3]
      #print(timestamp)
      
      ts_total += [timestamp] * len(latarr)
      latarr_total += latarr
      lonarr_total += lonarr
      temparr_total += temparr
      humidityarr_total += humidityarr
      vwindarr_total += vwindarr
      uwindarr_total += uwindarr
      cloud_water_total += preparr


      
      #print(ct)
      
  df["timestamp"]  = ts_total
  df["latitude"] = latarr_total
  df["longitude"] = lonarr_total
  df["temperature"] = temparr_total
  df["humidity"] = humidityarr_total
  df["v_component"] = vwindarr_total
  df["u_component"] = uwindarr_total
  df["precipitation"] = cloud_water_total

  from tabulate import tabulate
  #print(tabulate(df.head(n=5)))

  df.to_csv("2016{}.csv".format(date))
# Out:
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0201
# 0202
# 0203
# 0204
# 0205
# 0206
# 0207
# 0208
# 0209
# 0210
# 0211
# 0212
# 0213
# 0214
# 0215
# 0216
# 0217
# 0218
# 0219
# 0220
# 0221
# 0222
# 0223
# 0224
# 0225
# 0226
# 0227
# 0228
# 0229
# 0301
# 0302
# 0303
# 0304
# 0305
# 0306
# 0307
# 0308
# 0309
# 0310
# 0311
# 0312
# 0313
# 0314
# 0315
# 0316
# 0317
# 0318
# 0319
# 0320
# 0321
# 0322
# 0323
# 0324
# 0325
# 0326
# 0327
# 0328
# 0329
# 0330
# 0331

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !zip 2016_jan_mar.zip *.csv
# Out:
#   adding: 20160101.csv (deflated 76%)
#   adding: 20160102.csv (deflated 76%)
#   adding: 20160103.csv (deflated 76%)
#   adding: 20160104.csv (deflated 76%)
#   adding: 20160105.csv (deflated 76%)
#   adding: 20160106.csv (deflated 77%)
#   adding: 20160107.csv (deflated 77%)
#   adding: 20160108.csv (deflated 77%)
#   adding: 20160109.csv (deflated 75%)
#   adding: 20160110.csv (deflated 75%)
#   adding: 20160111.csv (deflated 76%)
#   adding: 20160112.csv (deflated 75%)
#   adding: 20160113.csv (deflated 75%)
#   adding: 20160114.csv (deflated 76%)
#   adding: 20160115.csv (deflated 75%)
#   adding: 20160116.csv (deflated 75%)
#   adding: 20160117.csv (deflated 75%)
#   adding: 20160118.csv (deflated 75%)
#   adding: 20160119.csv (deflated 75%)
#   adding: 20160120.csv (deflated 76%)
#   adding: 20160121.csv (deflated 75%)
#   adding: 20160122.csv (deflated 74%)
#   adding: 20160123.csv (deflated 76%)
#   adding: 20160124.csv (deflated 77%)
#   adding: 20160125.csv (deflated 76%)
#   adding: 20160126.csv (deflated 76%)
#   adding: 20160127.csv (deflated 76%)
#   adding: 20160128.csv (deflated 75%)
#   adding: 20160129.csv (deflated 74%)
#   adding: 20160130.csv (deflated 75%)
#   adding: 20160131.csv (deflated 76%)
#   adding: 20160201.csv (deflated 77%)
#   adding: 20160202.csv (deflated 76%)
#   adding: 20160203.csv (deflated 76%)
#   adding: 20160204.csv (deflated 76%)
#   adding: 20160205.csv (deflated 77%)
#   adding: 20160206.csv (deflated 76%)
#   adding: 20160207.csv (deflated 76%)
#   adding: 20160208.csv (deflated 77%)
#   adding: 20160209.csv (deflated 76%)
#   adding: 20160210.csv (deflated 75%)
#   adding: 20160211.csv (deflated 76%)
#   adding: 20160212.csv (deflated 76%)
#   adding: 20160213.csv (deflated 76%)
#   adding: 20160214.csv (deflated 75%)
#   adding: 20160215.csv (deflated 76%)
#   adding: 20160216.csv (deflated 76%)
#   adding: 20160217.csv (deflated 75%)
#   adding: 20160218.csv (deflated 76%)
#   adding: 20160219.csv (deflated 77%)
#   adding: 20160220.csv (deflated 77%)
#   adding: 20160221.csv (deflated 76%)
#   adding: 20160222.csv (deflated 76%)
#   adding: 20160223.csv (deflated 76%)
#   adding: 20160224.csv (deflated 76%)
#   adding: 20160225.csv (deflated 77%)
#   adding: 20160226.csv (deflated 76%)
#   adding: 20160227.csv (deflated 74%)
#   adding: 20160228.csv (deflated 75%)
#   adding: 20160229.csv (deflated 76%)
#   adding: 20160301.csv (deflated 76%)
#   adding: 20160302.csv (deflated 76%)
#   adding: 20160303.csv (deflated 75%)
#   adding: 20160304.csv (deflated 75%)
#   adding: 20160305.csv (deflated 75%)
#   adding: 20160306.csv (deflated 76%)
#   adding: 20160307.csv (deflated 76%)
#   adding: 20160308.csv (deflated 77%)
#   adding: 20160309.csv (deflated 75%)
#   adding: 20160310.csv (deflated 75%)
#   adding: 20160311.csv (deflated 75%)
#   adding: 20160312.csv (deflated 76%)
#   adding: 20160313.csv (deflated 76%)
#   adding: 20160314.csv (deflated 76%)
#   adding: 20160315.csv (deflated 76%)
#   adding: 20160316.csv (deflated 75%)
#   adding: 20160317.csv (deflated 75%)
#   adding: 20160318.csv (deflated 74%)
#   adding: 20160319.csv (deflated 75%)
#   adding: 20160320.csv (deflated 74%)
#   adding: 20160321.csv (deflated 76%)
#   adding: 20160322.csv (deflated 76%)
#   adding: 20160323.csv (deflated 77%)
#   adding: 20160324.csv (deflated 75%)
#   adding: 20160325.csv (deflated 75%)
#   adding: 20160326.csv (deflated 75%)
#   adding: 20160327.csv (deflated 74%)
#   adding: 20160328.csv (deflated 76%)
#   adding: 20160329.csv (deflated 77%)
#   adding: 20160330.csv (deflated 76%)
#   adding: 20160331.csv (deflated 76%)

# %%
# !cp 2016_jan_mar.zip drive/My\ Drive/'BadgerX Data'/NARR_2010_2019_data/NARR_2016

# %%
# !rm *.csv
